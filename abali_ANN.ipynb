# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import LabelEncoder , OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values
X
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
def preprocessing(X,y):
    #label encoding 1 , 2
    labelencoder_1 = LabelEncoder()
    X[:, 1] = labelencoder_1.fit_transform(X[:, 1])
    labelencoder_2 = LabelEncoder()
    X[:, 2] = labelencoder_2.fit_transform(X[:, 2])
    
    #column transform
    columnTransformer = ColumnTransformer(
        [('one_hot_encoder', OneHotEncoder(categories='auto'), [1,2])],    # The column numbers to be transformed (here is [3] but can be [0, 1, 3])
        remainder='passthrough'
    )
    X = columnTransformer.fit_transform(X)
    
    #Dummy trap
    X = np.delete(X, 3 , axis=1)
    X = np.delete(X, 0 , axis=1)
    
    # Splitting the dataset into the Training set and Test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
    X_train = X_train.astype(float)
    X_test = X_test.astype(float)
    # Feature Scaling
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    return (X_train, X_test, y_train, y_test)

# %%
X_train, X_test, y_train, y_test = preprocessing(X,y)

# %%
# Part 2 - Now let's make the ANN!
classifier = Sequential()
#first_hidden layer
classifier.add(
    Dense(
        units = 6,
        kernel_initializer = 'uniform',
        activation = 'relu',
        input_dim = X_train.shape[1]
    )
)
#second layer
classifier.add(
    Dense(
        units = 6,
        kernel_initializer = 'uniform',
        activation = 'relu',
        input_dim = 6
    )
)

#output layer
classifier.add(
    Dense(
        units = 1,
        kernel_initializer = 'uniform',
        activation = 'sigmoid',
        input_dim = 6
    )
)

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

#fitting
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 1s 121us/step - loss: 0.4812 - accuracy: 0.7954
# Epoch 2/100
# 8000/8000 [==============================] - 1s 111us/step - loss: 0.4262 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.4211 - accuracy: 0.8026
# Epoch 4/100
# 8000/8000 [==============================] - 1s 108us/step - loss: 0.4173 - accuracy: 0.8253
# Epoch 5/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.4160 - accuracy: 0.8288
# Epoch 6/100
# 8000/8000 [==============================] - 1s 109us/step - loss: 0.4140 - accuracy: 0.8303
# Epoch 7/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.4127 - accuracy: 0.8319
# Epoch 8/100
# 8000/8000 [==============================] - 1s 106us/step - loss: 0.4111 - accuracy: 0.83290s -
# Epoch 9/100
# 8000/8000 [==============================] - 1s 112us/step - loss: 0.4105 - accuracy: 0.8332
# Epoch 10/100
# ...

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
# accuracy of test data
cm = confusion_matrix(y_test, y_pred)

# %%
accuracy = (cm[0,0]+cm[1,1])/cm.sum() #(true positive + true negative) / total     
#tp fp
#fn tn
accuracy
# Out:
# 0.8465
